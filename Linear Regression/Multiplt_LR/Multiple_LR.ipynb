# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
try:
    df = pd.read_csv("/home/vipul/Machine Learning/Linear Regression/Multiplt_LR/Student_Performance.csv")
except:
    print("File not found")

# %%
df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
# sns.pairplot(df)
# plt.show()

plt.scatter(df['Hours Studied'], df['Previous Scores'])

# %%
# sns.pairplot(df, hue='Performance Index')
# plt.show()
sns.regplot(x=df['Hours Studied'], y=df['Previous Scores'])
# Out:
# <AxesSubplot: xlabel='Hours Studied', ylabel='Previous Scores'>

# %%
df['Extracurricular Activities'] = df['Extracurricular Activities'].map({'Yes':1, 'No': 0})
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
df.corr()
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# ...

# %%
X = df[['Hours Studied', 'Previous Scores', 'Extracurricular Activities', 'Sleep Hours', 'Sample Question Papers Practiced']]
X
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
y = df['Performance Index']
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 8371              3               81                           1            8
# 5027              1               88                           1            8
# 9234              5               54                           1            7
# 3944              2               49                           0            8
# 6862              1               71                           1            6
# ...             ...              ...                         ...          ...
# 5734              8               50                           1            6
# 5191              4               68                           0            9
# 5390              9               48                           0            7
# 860               1               47                           0            9
# 7270              2               46                           0            6
#
# ...

# %%
X_test
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 6252              5               69                           0            8
# 4684              2               46                           1            4
# 1731              7               56                           1            7
# 4742              6               42                           1            8
# 4521              7               53                           0            4
# ...             ...              ...                         ...          ...
# 1744              8               46                           0            9
# 9754              7               74                           1            7
# 6094              6               55                           1            7
# 8781              1               96                           0            7
# 9401              3               64                           1            5
#
# ...

# %%
y_train
# Out:
# 8371    62.0
# 5027    64.0
# 9234    38.0
# 3944    25.0
# 6862    47.0
#         ...
# 5734    48.0
# 5191    51.0
# 5390    44.0
# 860     20.0
# 7270    24.0
# Name: Performance Index, Length: 6700, dtype: float64

# %%
y_test
# Out:
# 6252    51.0
# 4684    20.0
# 1731    46.0
# 4742    28.0
# 4521    41.0
#         ...
# 1744    39.0
# 9754    69.0
# 6094    44.0
# 8781    72.0
# 9401    44.0
# Name: Performance Index, Length: 3300, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression(n_jobs=-1)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
# cross validation
from sklearn.model_selection import cross_val_score
cross_validation_score = cross_val_score(reg, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
cross_validation_score
# Out:
# array([-4.47348517, -4.09087668, -4.10610044, -4.29860964, -4.04928895])

# %%
#  find avg of cross_val_score
np.mean(cross_validation_score)
# Out:
# -4.203672174035443

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([54.75354173, 22.60032219, 47.92590021, ..., 43.12654287,
#        71.56089039, 43.10599732])

# %%
print("Cofiecient or Slope", reg.coef_)
print("Intercept", reg.intercept_)
# Out:
# Cofiecient or Slope [ 7.42463143 17.59967451  0.29139082  0.81391366  0.53092099]
# Intercept 55.401044776119406

# %%
# plt.scatter(X_train, y_train)
plt.plot(X_train, reg.predict(X_train))

# %%
# prediction for the test data
y_pred1 = reg.predict(scaler.transform([[7,99,1,9,1]]))
y_pred1
# Out:
# /usr/lib/python3/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([91.81278781])

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([54.75354173, 22.60032219, 47.92590021, ..., 43.12654287,
#        71.56089039, 43.10599732])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("mse:", mse)
print("mae:" ,mae)
print("rmse:" ,rmse)
# Out:
# mse: 4.073002572636013
# mae: 1.6090205581430632
# rmse: 2.0181681229857964

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)
score
# Out:
# 0.9890100898437779

# %%
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9889934081343726

# %% [markdown]
# ## Assumptions

# %%
plt.scatter(y_test, y_pred)
# plot should be have linear relationship if it has linear relationship it means your model has been performed well

# %%
# Calculate Error
residuals = y_test - y_pred
print(residuals)
# Out:
# 6252   -3.753542
# 4684   -2.600322
# 1731   -1.925900
# 4742   -3.329356
# 4521   -2.044170
#           ...
# 1744   -2.003116
# 9754    2.979036
# 6094    0.873457
# 8781    0.439110
# 9401    0.894003
# Name: Performance Index, Length: 3300, dtype: float64

# %% [markdown]
# ## Plot this residuals or error with the help of seaborn displot
# If you are getting a normal distribution then it indicate your model is good

# %%
## Plot this residuals or error with the help of seaborn
sns.displot(residuals, kind='kde')

# %%
## Create a Scatter plot with respect to residuals and prediction
plt.scatter(y_pred, residuals)

# Note: this data should be uniformaly distributed it means your data should not create any kind pattern

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, X_train).fit()

# %%
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array([ -0.64750305, -32.80072259,  -7.47514456, ..., -12.27450191,
#         16.15984562, -12.29504746])

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      Performance Index   R-squared (uncentered):                   0.106
# Model:                            OLS   Adj. R-squared (uncentered):              0.105
# Method:                 Least Squares   F-statistic:                              158.6
# Date:                Mon, 22 Jul 2024   Prob (F-statistic):                   9.18e-160
# Time:                        20:13:52   Log-Likelihood:                         -36409.
# No. Observations:                6700   AIC:                                  7.283e+04
# Df Residuals:                    6695   BIC:                                  7.286e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# predict for new data

model.predict(scaler.transform([[2	,98,	0,	10,	7]]))
# Out:
# /usr/lib/python3/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([22.11549728])
